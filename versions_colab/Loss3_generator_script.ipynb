# %% [markdown]
# #RESULT №5

# %%
import os
from google.colab import drive
drive.mount('/content/drive/')
import sys
sys.path.insert(0, '/content/drive/My Drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np

#1
os.chdir("/content/drive/My Drive/results/Structures/v1_28/Adam")
ld_lossG_Adam28 = []
with open('v1_28-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_Adam28.append(float(item))

ld_lossD_Adam28 = []
with open('v1_28-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_Adam28.append(float(item))

os.chdir("/content/drive/My Drive/results/Structures/v1_36/Adam")

ld_lossG_Adam36 = []
with open('v1_36-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_Adam36.append(float(item))

ld_lossD_Adam36 = []
with open('v1_36-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_Adam36.append(float(item))

ld_lossG_Adam28_36 = np.concatenate((ld_lossG_Adam28, ld_lossG_Adam36), axis=None)
ld_lossD_Adam28_36 = np.concatenate((ld_lossD_Adam28, ld_lossD_Adam36), axis=None)

print(len(ld_lossG_Adam28_36))
print(len(ld_lossD_Adam28_36))
print()

#2
os.chdir("/content/drive/My Drive/results/Structures/v1_28/RMSprop")
ld_lossG_RMSprop28 = []
with open('v1_28-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_RMSprop28.append(float(item))

ld_lossD_RMSprop28 = []
with open('v1_28-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_RMSprop28.append(float(item))


os.chdir("/content/drive/My Drive/results/Structures/v1_36/RMSprop")

ld_lossG_RMSprop36 = []
with open('v1_36-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_RMSprop36.append(float(item))

ld_lossD_RMSprop36 = []
with open('v1_36-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_RMSprop36.append(float(item))

ld_lossG_RMSprop28_36 = np.concatenate((ld_lossG_RMSprop28, ld_lossG_RMSprop36), axis=None)
ld_lossD_RMSprop28_36 = np.concatenate((ld_lossD_RMSprop28, ld_lossD_RMSprop36), axis=None)

print(len(ld_lossG_RMSprop28_36))
print(len(ld_lossD_RMSprop28_36))
print()

#3
os.chdir("/content/drive/My Drive/results/Structures/v1_33/Adam")
ld_lossG_Adam33 = []
with open('v1_33-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_Adam33.append(float(item))

ld_lossD_Adam33 = []
with open('v1_33-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_Adam33.append(float(item))

os.chdir("/content/drive/My Drive/results/Structures/v1_37/Adam")
ld_lossG_Adam37 = []
with open('v1_37-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_Adam37.append(float(item))

ld_lossD_Adam37 = []
with open('v1_37-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_Adam37.append(float(item))

ld_lossG_Adam33_37 = np.concatenate((ld_lossG_Adam33, ld_lossG_Adam37), axis=None)
ld_lossD_Adam33_37 = np.concatenate((ld_lossD_Adam33, ld_lossD_Adam37), axis=None)

print(len(ld_lossG_Adam33_37))
print(len(ld_lossD_Adam33_37))
print()

#4
os.chdir("/content/drive/My Drive/results/Structures/v1_33/RMSprop")
ld_lossG_RMSprop33 = []
with open('v1_33-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_RMSprop33.append(float(item))

ld_lossD_RMSprop33 = []
with open('v1_33-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_RMSprop33.append(float(item))

os.chdir("/content/drive/My Drive/results/Structures/v1_37/RMSprop")
ld_lossG_RMSprop37 = []
with open('v1_37-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_RMSprop37.append(float(item))

ld_lossD_RMSprop37 = []
with open('v1_37-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_RMSprop37.append(float(item))

ld_lossG_RMSprop33_37 = np.concatenate((ld_lossG_RMSprop33, ld_lossG_RMSprop37), axis=None)
ld_lossD_RMSprop33_37 = np.concatenate((ld_lossD_RMSprop33, ld_lossD_RMSprop37), axis=None)

print(len(ld_lossG_RMSprop33_37))
print(len(ld_lossD_RMSprop33_37))
print()

os.chdir("/content/drive/My Drive/trash")
# Out:
# 2500
# 2500
#
# 2500
# 2500
#
# 2500
# 2500
#
# 2500
# 2500

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
plt.grid(color='black')
#plt.title("Generator Loss During Training", color='black', size = 20)
plt.title("Discriminator Loss During Training", color='black', size = 20)

# #Generator part
# plt.plot(ld_lossD_Adam28_36,label="Adam Generator fiveD & oneG", color='#00994C')
# plt.plot(ld_lossD_RMSprop28_36,label="RMSprop Generator fiveD & oneG", color='#0000FF')

# plt.plot(ld_lossD_Adam33_37,label="Adam Generator oneD & threeG", color='#009999')
# plt.plot(ld_lossD_RMSprop33_37,label="RMSprop Generator oneD & threeG", color='#001933')

#Discriminator part
plt.plot(ld_lossD_Adam28_36,label="Adam Discriminator fiveD & oneG", color='#999900')
plt.plot(ld_lossD_RMSprop28_36,label="RMSprop Discriminator fiveD & oneG", color='#CC0066')

plt.plot(ld_lossD_Adam33_37,label="Adam Discriminator oneD & threeG", color='orange')
plt.plot(ld_lossD_RMSprop33_37,label="RMSprop Discriminator oneD & threeG", color='#330019')



plt.rc('font', size=15)

plt.xlabel("Epochs", color='black', size = 13)
plt.ylabel("Loss", color='black', size=13)
ax.tick_params(axis='x', colors='black')
ax.tick_params(axis='y', colors='black')
import matplotlib.ticker as plticker
loc = plticker.MultipleLocator(base=200)
locY = plticker.MultipleLocator(base=0.2)
ax.xaxis.set_major_locator(loc)
ax.yaxis.set_major_locator(locY)
#plt.xlim(0,2300)
plt.ylim(0,3)
plt.legend()
fig.savefig('Losses_nb_5_fewGfewD_discr' + '.png')
