# %% [markdown]
# #RESULT №1

# %%
import os
from google.colab import drive
drive.mount('/content/drive/')
import sys
sys.path.insert(0, '/content/drive/My Drive/')
# Out:
# Mounted at /content/drive/

# %%
os.chdir("/content/drive/My Drive/results/Structures/v1_14/Adam")
ld_lossG_Adam = []
with open('v1_14-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_Adam.append(float(item))

ld_lossD_Adam = []
with open('v1_14-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_Adam.append(float(item))

print(len(ld_lossG_Adam))
print(len(ld_lossD_Adam))

os.chdir("/content/drive/My Drive/results/Structures/v1_14/RMSprop")
ld_lossG_RMSprop = []
with open('v1_14-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_RMSprop.append(float(item))

ld_lossD_RMSprop = []
with open('v1_14-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_RMSprop.append(float(item))

print(len(ld_lossG_RMSprop))
print(len(ld_lossD_RMSprop))

os.chdir("/content/drive/My Drive/results/Structures/v1_14/SGD")
ld_lossG_SGD = []
with open('v1_14-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_SGD.append(float(item))

ld_lossD_SGD = []
with open('v1_14-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_SGD.append(float(item))

print(len(ld_lossG_SGD))
print(len(ld_lossD_SGD))

os.chdir("/content/drive/My Drive/trash")
# Out:
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
plt.grid(color='black')
plt.title("Generator Loss During Training", color='black', size = 20)
#plt.title("Discriminator Loss During Training", color='black', size = 20)
plt.plot(ld_lossG_Adam,label="Adam Generator")
#plt.plot(ld_lossD_Adam,label="Adam Discriminator", color='orange')
plt.plot(ld_lossG_RMSprop,label="RMSprop Generator")
#plt.plot(ld_lossD_RMSprop,label="RMSprop Discriminator", color='red')
plt.plot(ld_lossG_SGD,label="SGD Generator")
#plt.plot(ld_lossD_SGD,label="SGD Discriminator", color='brown')

plt.rc('font', size=15) 

plt.xlabel("Epochs", color='black', size = 13)
plt.ylabel("Loss", color='black', size=13)
ax.tick_params(axis='x', colors='black')
ax.tick_params(axis='y', colors='black')
import matplotlib.ticker as plticker
loc = plticker.MultipleLocator(base=100)
locY = plticker.MultipleLocator(base=5)
ax.xaxis.set_major_locator(loc)
ax.yaxis.set_major_locator(locY)
plt.ylim(0,75)
plt.legend()
#fig.savefig('Losses_nb_1_differentOptim_discr' + '.png')
fig.savefig('Losses_nb_1_differentOptim_gen' + '.png')

# %% [markdown]
# #RESULT №2

# %%
import os
from google.colab import drive
drive.mount('/content/drive/')
import sys
sys.path.insert(0, '/content/drive/My Drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
#1
os.chdir("/content/drive/My Drive/results/Structures/v1_19/Adam")
ld_lossG_Adam19 = []
with open('v1_19-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_Adam19.append(float(item))

ld_lossD_Adam19 = []
with open('v1_19-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_Adam19.append(float(item))

print(len(ld_lossG_Adam19))
print(len(ld_lossD_Adam19))

#2
os.chdir("/content/drive/My Drive/results/Structures/v1_20/Adam")
ld_lossG_Adam20 = []
with open('v1_20-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_Adam20.append(float(item))

ld_lossD_Adam20 = []
with open('v1_20-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_Adam20.append(float(item))

print(len(ld_lossG_Adam20))
print(len(ld_lossD_Adam20))

#3
os.chdir("/content/drive/My Drive/results/Structures/v1_19/RMSprop")
ld_lossG_RMSprop19 = []
with open('v1_19-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_RMSprop19.append(float(item))

ld_lossD_RMSprop19 = []
with open('v1_19-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_RMSprop19.append(float(item))

print(len(ld_lossG_RMSprop19))
print(len(ld_lossD_RMSprop19))

#4
os.chdir("/content/drive/My Drive/results/Structures/v1_20/RMSprop")
ld_lossG_RMSprop20 = []
with open('v1_20-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_RMSprop20.append(float(item))

ld_lossD_RMSprop20 = []
with open('v1_20-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_RMSprop20.append(float(item))

print(len(ld_lossG_RMSprop20))
print(len(ld_lossD_RMSprop20))

os.chdir("/content/drive/My Drive/trash")
# Out:
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
plt.grid(color='black')
plt.title("Generator Loss During Training", color='black', size = 20)
#plt.title("Discriminator Loss During Training", color='black', size = 20)

plt.plot(ld_lossG_Adam19,label="Adam Generator (beta1 = 0.9)", color='#000099')
#plt.plot(ld_lossD_Adam19,label="Adam Discriminator (beta1 = 0.9)", color='orange')
plt.plot(ld_lossG_Adam20,label="Adam Generator (beta1 = 0.5)", color='#404040')
#plt.plot(ld_lossD_Adam20,label="Adam Discriminator (beta1 = 0.5)", color='yellow')

plt.plot(ld_lossG_RMSprop19,label="RMSprop Generator (beta1 = 0.9)", color='#4C0099')
#plt.plot(ld_lossD_RMSprop19,label="RMSprop Discriminator (beta1 = 0.9)", color='red')
plt.plot(ld_lossG_RMSprop20,label="RMSprop Generator (beta1 = 0.5)", color='brown')
#plt.plot(ld_lossD_RMSprop20,label="RMSprop Discriminator (beta1 = 0.5)", color='green')

plt.rc('font', size=15) 

plt.xlabel("Epochs", color='black', size = 13)
plt.ylabel("Loss", color='black', size=13)
ax.tick_params(axis='x', colors='black')
ax.tick_params(axis='y', colors='black')
import matplotlib.ticker as plticker
loc = plticker.MultipleLocator(base=100)
locY = plticker.MultipleLocator(base=5)
ax.xaxis.set_major_locator(loc)
ax.yaxis.set_major_locator(locY)
plt.ylim(0,30)
plt.legend()
#fig.savefig('Losses_nb_2_differentHyper_discr' + '.png')
fig.savefig('Losses_nb_2_differentHyper_gen' + '.png')

# %% [markdown]
# #Result №3

# %% [markdown]
# ##A

# %%
import os
from google.colab import drive
drive.mount('/content/drive/')
import sys
sys.path.insert(0, '/content/drive/My Drive/')

# %%
#1
os.chdir("/content/drive/My Drive/results/Structures/v1_15/RMSprop")
ld_lossG_RMSprop15 = []
with open('v1_15-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_RMSprop15.append(float(item))

ld_lossD_RMSprop15 = []
with open('v1_15-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_RMSprop15.append(float(item))

print(len(ld_lossG_RMSprop15))
print(len(ld_lossD_RMSprop15))

#2
os.chdir("/content/drive/My Drive/results/Structures/v1_16/RMSprop")
ld_lossG_RMSprop16 = []
with open('v1_16-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_RMSprop16.append(float(item))

ld_lossD_RMSprop16 = []
with open('v1_16-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_RMSprop16.append(float(item))

print(len(ld_lossG_RMSprop16))
print(len(ld_lossD_RMSprop16))

#3
os.chdir("/content/drive/My Drive/results/Structures/v1_17/RMSprop")
ld_lossG_RMSprop17 = []
with open('v1_17-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_RMSprop17.append(float(item))

ld_lossD_RMSprop17 = []
with open('v1_17-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_RMSprop17.append(float(item))

print(len(ld_lossG_RMSprop17))
print(len(ld_lossD_RMSprop17))

#4
os.chdir("/content/drive/My Drive/results/Structures/v1_18/RMSprop")
ld_lossG_RMSprop18 = []
with open('v1_18-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_RMSprop18.append(float(item))

ld_lossD_RMSprop18 = []
with open('v1_18-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_RMSprop18.append(float(item))

print(len(ld_lossG_RMSprop18))
print(len(ld_lossD_RMSprop18))

#5
os.chdir("/content/drive/My Drive/results/Structures/v1_19/RMSprop")
ld_lossG_RMSprop19 = []
with open('v1_19-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_RMSprop19.append(float(item))

ld_lossD_RMSprop19 = []
with open('v1_19-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_RMSprop19.append(float(item))

print(len(ld_lossG_RMSprop19))
print(len(ld_lossD_RMSprop19))

#6
os.chdir("/content/drive/My Drive/results/Structures/v1_25/RMSprop")
ld_lossG_RMSprop25 = []
with open('v1_25-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_RMSprop25.append(float(item))
ld_lossG_RMSprop25 = ld_lossG_RMSprop25[0:1000] 

ld_lossD_RMSprop25 = []
with open('v1_25-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_RMSprop25.append(float(item))
ld_lossD_RMSprop25 = ld_lossD_RMSprop25[0:1000]

print(len(ld_lossG_RMSprop25))
print(len(ld_lossD_RMSprop25))

os.chdir("/content/drive/My Drive/trash")

#7
os.chdir("/content/drive/My Drive/results/Structures/v1_31/RMSprop")
ld_lossG_RMSprop31 = []
with open('v1_31-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_RMSprop31.append(float(item))
ld_lossG_RMSprop31 = ld_lossG_RMSprop31[0:1000] 

ld_lossD_RMSprop31 = []
with open('v1_31-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_RMSprop31.append(float(item))
ld_lossD_RMSprop31 = ld_lossD_RMSprop31[0:1000]

#8
os.chdir("/content/drive/My Drive/results/Structures/v1_32/RMSprop")
ld_lossG_RMSprop32 = []
with open('v1_32-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_RMSprop32.append(float(item))
ld_lossG_RMSprop32 = ld_lossG_RMSprop32[0:1000] 

ld_lossD_RMSprop32 = []
with open('v1_32-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_RMSprop32.append(float(item))
ld_lossD_RMSprop32 = ld_lossD_RMSprop32[0:1000]


print(len(ld_lossG_RMSprop32))
print(len(ld_lossD_RMSprop32))

os.chdir("/content/drive/My Drive/trash")
# Out:
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
plt.grid(color='black')
plt.title("Generator Loss During Training", color='black', size = 20)
#plt.title("Discriminator Loss During Training", color='black', size = 20)

plt.plot(ld_lossG_RMSprop15,label="RMSprop Generator (bs = 32)", color='#001933')
#plt.plot(ld_lossD_RMSprop15,label="RMSprop Discriminator (bs = 32)", color='#330019')

plt.plot(ld_lossG_RMSprop16,label="RMSprop Generator (bs = 64)", color='#000066')
#plt.plot(ld_lossD_RMSprop16,label="RMSprop Discriminator (bs = 64)", color='#660033')

plt.plot(ld_lossG_RMSprop17,label="RMSprop Generator (bs = 128)", color='#0000FF')
#plt.plot(ld_lossD_RMSprop17,label="RMSprop Discriminator (bs = 128)", color='#CC0066')

plt.plot(ld_lossG_RMSprop18,label="RMSprop Generator (bs = 256)", color='#003319')
#plt.plot(ld_lossD_RMSprop18,label="RMSprop Discriminator (bs = 256)", color='#333300')

plt.plot(ld_lossG_RMSprop19,label="RMSprop Generator (bs = 512)", color='#00994C')
#plt.plot(ld_lossD_RMSprop19,label="RMSprop Discriminator (bs = 512)", color='#999900')

plt.plot(ld_lossG_RMSprop25,label="RMSprop Generator (bs = 1024)", color='#00FF80')
#plt.plot(ld_lossD_RMSprop25,label="RMSprop Discriminator (bs = 1024)", color='#FFFF00')

plt.plot(ld_lossG_RMSprop31,label="RMSprop Generator (bs = 2048)", color='#009999')
#plt.plot(ld_lossD_RMSprop31,label="RMSprop Discriminator (bs = 2048)", color='#990000')

plt.plot(ld_lossG_RMSprop32,label="RMSprop Generator (bs = 4096)", color='#00FFFF')
#plt.plot(ld_lossD_RMSprop32,label="RMSprop Discriminator (bs = 4096)", color='#FF0000')

plt.rc('font', size=15) 

plt.xlabel("Epochs", color='black', size = 13)
plt.ylabel("Loss", color='black', size=13)
ax.tick_params(axis='x', colors='black')
ax.tick_params(axis='y', colors='black')
import matplotlib.ticker as plticker
loc = plticker.MultipleLocator(base=100)
locY = plticker.MultipleLocator(base=5)
ax.xaxis.set_major_locator(loc)
ax.yaxis.set_major_locator(locY)
plt.ylim(0,25)
plt.legend()
#fig.savefig('Losses_nb_3_differentBS_RMSprop_discr' + '.png')
fig.savefig('Losses_nb_3_differentBS_RMSprop_gen' + '.png')

# %% [markdown]
# ##B

# %%
import os
from google.colab import drive
drive.mount('/content/drive/')
import sys
sys.path.insert(0, '/content/drive/My Drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
#1
os.chdir("/content/drive/My Drive/results/Structures/v1_14/Adam")
ld_lossG_Adam14 = []
with open('v1_14-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_Adam14.append(float(item))

ld_lossD_Adam14 = []
with open('v1_14-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_Adam14.append(float(item))

print(len(ld_lossG_Adam14))
print(len(ld_lossD_Adam14))

#2
os.chdir("/content/drive/My Drive/results/Structures/v1_11/Adam")
ld_lossG_Adam11 = []
with open('v1_11-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_Adam11.append(float(item))
ld_lossG_Adam11 = ld_lossG_Adam11[0:1000] 

ld_lossD_Adam11 = []
with open('v1_11-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_Adam11.append(float(item))
ld_lossD_Adam11 = ld_lossD_Adam11[0:1000] 

print(len(ld_lossG_Adam11))
print(len(ld_lossD_Adam11))

#3
os.chdir("/content/drive/My Drive/results/Structures/v1_21/Adam")
ld_lossG_Adam21 = []
with open('v1_21-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_Adam21.append(float(item))

ld_lossD_Adam21 = []
with open('v1_21-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_Adam21.append(float(item))

print(len(ld_lossG_Adam21))
print(len(ld_lossD_Adam21))

#4
os.chdir("/content/drive/My Drive/results/Structures/v1_30/Adam")
ld_lossG_Adam30 = []
with open('v1_30-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_Adam30.append(float(item))

ld_lossD_Adam30 = []
with open('v1_30-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_Adam30.append(float(item))

print(len(ld_lossG_Adam30))
print(len(ld_lossD_Adam30))

#5
os.chdir("/content/drive/My Drive/results/Structures/v1_20/Adam")
ld_lossG_Adam20 = []
with open('v1_20-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_Adam20.append(float(item))

ld_lossD_Adam20 = []
with open('v1_20-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_Adam20.append(float(item))

print(len(ld_lossG_Adam20))
print(len(ld_lossD_Adam20))

#6
os.chdir("/content/drive/My Drive/results/Structures/v1_25/Adam")
ld_lossG_Adam25 = []
with open('v1_25-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_Adam25.append(float(item))
ld_lossG_Adam25 = ld_lossG_Adam25[0:1000] 

ld_lossD_Adam25 = []
with open('v1_25-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_Adam25.append(float(item))
ld_lossD_Adam25 = ld_lossD_Adam25[0:1000] 

print(len(ld_lossG_Adam25))
print(len(ld_lossD_Adam25))

#7
os.chdir("/content/drive/My Drive/results/Structures/v1_31/Adam")
ld_lossG_Adam31 = []
with open('v1_31-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_Adam31.append(float(item))
ld_lossG_Adam31 = ld_lossG_Adam31[0:1000] 

ld_lossD_Adam31 = []
with open('v1_31-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_Adam31.append(float(item))
ld_lossD_Adam31 = ld_lossD_Adam31[0:1000] 

print(len(ld_lossG_Adam31))
print(len(ld_lossD_Adam31))

#8
os.chdir("/content/drive/My Drive/results/Structures/v1_32/Adam")
ld_lossG_Adam32 = []
with open('v1_32-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_Adam32.append(float(item))
ld_lossG_Adam32 = ld_lossG_Adam32[0:1000] 

ld_lossD_Adam32 = []
with open('v1_32-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_Adam32.append(float(item))
ld_lossD_Adam32 = ld_lossD_Adam32[0:1000] 

print(len(ld_lossG_Adam32))
print(len(ld_lossD_Adam32))

os.chdir("/content/drive/My Drive/trash")
# Out:
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000
# 1000

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
plt.grid(color='black')
plt.title("Generator Loss During Training", color='black', size = 20)
#plt.title("Discriminator Loss During Training", color='black', size = 20)

plt.plot(ld_lossG_Adam14,label="Adam Generator (bs = 32)", color='#001933')
#plt.plot(ld_lossD_Adam14,label="Adam Discriminator (bs = 32)", color='#330019')

plt.plot(ld_lossG_Adam11,label="Adam Generator (bs = 64)", color='#000066')
#plt.plot(ld_lossD_Adam11,label="Adam Discriminator (bs = 64)", color='#660033')

plt.plot(ld_lossG_Adam21,label="Adam Generator (bs = 128)", color='#0000FF')
#plt.plot(ld_lossD_Adam21,label="Adam Discriminator (bs = 128)", color='#CC0066')

plt.plot(ld_lossG_Adam30,label="Adam Generator (bs = 256)", color='#003319')
#plt.plot(ld_lossD_Adam30,label="Adam Discriminator (bs = 256)", color='#333300')

plt.plot(ld_lossG_Adam20,label="Adam Generator (bs = 512)", color='#00994C')
#plt.plot(ld_lossD_Adam20,label="Adam Discriminator (bs = 512)", color='#999900')

plt.plot(ld_lossG_Adam25,label="Adam Generator (bs = 1024)", color='#00FF80')
#plt.plot(ld_lossD_Adam25,label="Adam Discriminator (bs = 1024)", color='#FFFF00')

plt.plot(ld_lossG_Adam31,label="Adam Generator (bs = 2048)", color='#009999')
#plt.plot(ld_lossD_Adam31,label="Adam Discriminator (bs = 2048)", color='#990000')

plt.plot(ld_lossG_Adam32,label="Adam Generator (bs = 4096)", color='#00FFFF')
#plt.plot(ld_lossD_Adam32,label="Adam Discriminator (bs = 4096)", color='#FF0000')

plt.rc('font', size=15)

plt.xlabel("Epochs", color='black', size = 13)
plt.ylabel("Loss", color='black', size=13)
ax.tick_params(axis='x', colors='black')
ax.tick_params(axis='y', colors='black')
import matplotlib.ticker as plticker
loc = plticker.MultipleLocator(base=100)
locY = plticker.MultipleLocator(base=5)
ax.xaxis.set_major_locator(loc)
ax.yaxis.set_major_locator(locY)
plt.ylim(0,25)
plt.legend()
#fig.savefig('Losses_nb_3_differentBS_Adam_discr' + '.png')
fig.savefig('Losses_nb_3_differentBS_Adam_gen' + '.png')

# %%
with open('x.txt', 'w') as f:
    for item in x:
        f.write("%s\n" % item)

# %%
os.chdir("/content/drive/My Drive/results/Structures/v1_11/RMSprop")

# %%
os.chdir("/content/drive/My Drive/trash")

# %%
ld_lossG = []
with open('v1_11-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG.append(float(item))

# %%
ld_lossD = []
with open('v1_11-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD.append(float(item))

# %%
ld_lossD_x = []
with open('v1_11-Dx_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_x.append(float(item))

# %%
ld_lossD_G_z1 = []
with open('v1_11-DGz1_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_G_z1.append(float(item))

# %%
ld_lossD_G_z2 = []
with open('v1_11-DGz2_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_G_z2.append(float(item))

# %%
print(len(ld_lossG))
print(len(ld_lossD))
print(len(ld_lossD_x))
print(len(ld_lossD_G_z1))
print(len(ld_lossD_G_z2))
# Out:
# 1400
# 1400
# 1400
# 1400
# 1400

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
plt.grid(color='black')
plt.title("Generator and Discriminator Loss During Training", color='black', size = 20)
plt.plot(ld_lossG,label="generator")
plt.plot(ld_lossD,label="discriminator")
plt.xlabel("Epochs", color='black', size = 13)
plt.ylabel("Loss", color='black', size=13)
ax.tick_params(axis='x', colors='black')
ax.tick_params(axis='y', colors='black')
import matplotlib.ticker as plticker
loc = plticker.MultipleLocator(base=100)
locY = plticker.MultipleLocator(base=5)
ax.xaxis.set_major_locator(loc)
ax.yaxis.set_major_locator(locY)
plt.legend()
fig.savefig('Losse' + '.png')

# %%
f_name_loss = "Loss_%dep_%dbs_%dis" % (opt.n_epochs, opt.batch_size, opt.img_size)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
plt.grid(color='black')
plt.title("Generator and Discriminator Loss During Training", color='black', size = 20)
plt.plot(G_losses_epochs_all[0],label="G_Adam")
plt.plot(D_losses_epochs_all[0],label="D_Adam")
plt.plot(G_losses_epochs_all[1],label="G_RMSprop")
plt.plot(D_losses_epochs_all[1],label="D_RMSprop")
plt.plot(G_losses_epochs_all[2],label="G_SGD")
plt.plot(D_losses_epochs_all[2],label="D_SGD")
plt.xlabel("Epochs", color='black', size = 13)
plt.ylabel("Loss", color='black', size=13)
ax.tick_params(axis='x', colors='black')
ax.tick_params(axis='y', colors='black')
import matplotlib.ticker as plticker
loc = plticker.MultipleLocator(base=50)
locY = plticker.MultipleLocator(base=5)
ax.xaxis.set_major_locator(loc)
ax.yaxis.set_major_locator(locY)
plt.legend()
fig.savefig('Losses/v1_11/v1_11-' + f_name_loss + '.png')

plt.ylim(-50,50)
fig.savefig('Losses/v1_11/v1_11-' + f_name_loss + '_2.png')
plt.ylim(0,50)
fig.savefig('Losses/v1_11/v1_11-' + f_name_loss + '_3.png')
plt.ylim(0,100)
fig.savefig('Losses/v1_11/v1_11-' + f_name_loss + '_4.png')
plt.ylim(0,20)
fig.savefig('Losses/v1_11/v1_11-' + f_name_loss + '_5.png')
plt.ylim(-100,100)
fig.savefig('Losses/v1_11/v1_11-' + f_name_loss + '_6.png')
plt.ylim(-10,10)
fig.savefig('Losses/v1_11/v1_11-' + f_name_loss + '_7.png')
plt.ylim(-20,20)
fig.savefig('Losses/v1_11/v1_11-' + f_name_loss + '_8.png')
plt.close(fig)
