# %% [markdown]
# #RESULT INCEPTION №1

# %%
import os
from google.colab import drive
drive.mount('/content/drive/')
import sys
sys.path.insert(0, '/content/drive/My Drive/')
# Out:
# Mounted at /content/drive/

# %%
#1
os.chdir("/content/drive/My Drive/results/Structures/v1_34/Adam")
ld_lossG_Adam34 = []
with open('v1_34-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_Adam34.append(float(item))

ld_lossD_Adam34 = []
with open('v1_34-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_Adam34.append(float(item))

print(len(ld_lossG_Adam34))
print(len(ld_lossD_Adam34))

#2
os.chdir("/content/drive/My Drive/results/Structures/v1_34/RMSprop")
ld_lossG_RMSprop34 = []
with open('v1_34-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_RMSprop34.append(float(item))

ld_lossD_RMSprop34 = []
with open('v1_34-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_RMSprop34.append(float(item))

print(len(ld_lossG_RMSprop34))
print(len(ld_lossD_RMSprop34))



os.chdir("/content/drive/My Drive/trash")
# Out:
# 1500
# 1500
# 1500
# 1500

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
plt.grid(color='black')
plt.title("Generator and Discriminator Loss During Training", color='black', size = 20)
#plt.title("Discriminator Loss During Training", color='black', size = 20)

# plt.plot(ld_lossG_Adam34,label="Adam Generator", color='#0000FF')
# plt.plot(ld_lossD_Adam34,label="Adam Discriminator", color='#CC0066')

plt.plot(ld_lossG_RMSprop34,label="RMSprop Generator", color='#00FFFF')
plt.plot(ld_lossD_RMSprop34,label="RMSprop Discriminator", color='#FF0000')


plt.xlabel("Epochs", color='black', size = 13)
plt.ylabel("Loss", color='black', size=13)
ax.tick_params(axis='x', colors='black')
ax.tick_params(axis='y', colors='black')
import matplotlib.ticker as plticker
loc = plticker.MultipleLocator(base=100)
locY = plticker.MultipleLocator(base=0.5)
ax.xaxis.set_major_locator(loc)
ax.yaxis.set_major_locator(locY)
plt.ylim(0,10)
plt.legend()
fig.savefig('Losses-Result_incM_nb1_Adam' + '.png')
#fig.savefig('Losses-Result_RMSprop_nb3_discr' + '.png')

# %%
#4
os.chdir("/content/drive/My Drive/results/Structures/v1_34/Adam")
ld_lossG_Adam1024 = []
with open('v1_34-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_Adam1024.append(float(item))

DGz2_Adam1024 = []
with open('v1_34-DGz2_Loss_ep.txt', 'r') as f:
    for item in f:
        DGz2_Adam1024.append(float(item))


ld_lossD_Adam1024 = []
with open('v1_34-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_Adam1024.append(float(item))

D_x_Adam1024 = []
with open('v1_34-Dx_Loss_ep.txt', 'r') as f:
    for item in f:
        D_x_Adam1024.append(float(item))

DGz1_Adam1024 = []
with open('v1_34-DGz1_Loss_ep.txt', 'r') as f:
    for item in f:
        DGz1_Adam1024.append(float(item))


print(len(ld_lossG_Adam1024))
print(len(ld_lossD_Adam1024))
print(len(D_x_Adam1024))
print(len(DGz1_Adam1024))
print(len(DGz2_Adam1024))
print()

#4a
os.chdir("/content/drive/My Drive/results/Structures/v1_34/RMSprop")
ld_lossG_RMSprop1024 = []
with open('v1_34-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_RMSprop1024.append(float(item))

DGz2_RMSprop1024 = []
with open('v1_34-DGz2_Loss_ep.txt', 'r') as f:
    for item in f:
        DGz2_RMSprop1024.append(float(item))


ld_lossD_RMSprop1024 = []
with open('v1_34-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_RMSprop1024.append(float(item))

D_x_RMSprop1024 = []
with open('v1_34-Dx_Loss_ep.txt', 'r') as f:
    for item in f:
        D_x_RMSprop1024.append(float(item))

DGz1_RMSprop1024 = []
with open('v1_34-DGz1_Loss_ep.txt', 'r') as f:
    for item in f:
        DGz1_RMSprop1024.append(float(item))


print(len(ld_lossG_RMSprop1024))
print(len(ld_lossD_RMSprop1024))
print(len(D_x_RMSprop1024))
print(len(DGz1_RMSprop1024))
print(len(DGz2_RMSprop1024))
print()

os.chdir("/content/drive/My Drive/trash")
# Out:
# 1500
# 1500
# 1500
# 1500
# 1500
#
# 1500
# 1500
# 1500
# 1500
# 1500

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
plt.grid(color='black')
plt.title("Generator and Discriminator Output During Training", color='black', size = 20)
#plt.title("Discriminator Loss During Training", color='black', size = 20)

plt.plot(D_x_Adam1024,label="D(x) [Adam; (bs = 1024)]", color='#330019')
plt.plot(DGz1_Adam1024,label="DG(z1) [Adam; (bs = 1024)]", color='#CC0066')
plt.plot(DGz2_Adam1024,label="DG(z2) [Adam; (bs = 1024)]", color='#999900')
plt.rc('font', size=15) 

# plt.plot(D_x_RMSprop1024,label="D(x) [RMSprop; (bs = 1024)]", color='#330019')
# plt.plot(DGz1_RMSprop1024,label="DG(z1) [RMSprop; (bs = 1024)]", color='#CC0066')
# plt.plot(DGz2_RMSprop1024,label="DG(z2) [RMSprop; (bs = 1024)]", color='#999900')
# plt.rc('font', size=15) 

plt.xlabel("Epochs", color='black', size = 13)
plt.ylabel("Output", color='black', size=13)
ax.tick_params(axis='x', colors='black')
ax.tick_params(axis='y', colors='black')
import matplotlib.ticker as plticker
loc = plticker.MultipleLocator(base=150)
locY = plticker.MultipleLocator(base=0.1)
ax.xaxis.set_major_locator(loc)
ax.yaxis.set_major_locator(locY)
#plt.xlim(0,2300)
plt.ylim(0,1)
plt.legend()
fig.savefig('Losses2-Result_nb3_IncM1_Adam1024' + '.png')
#fig.savefig('Losses2-Result_nb2_bs4096_discr' + '.png')

# %% [markdown]
# # RESULT №2 - continue of batch 4096

# %%
import os
from google.colab import drive
drive.mount('/content/drive/')
import sys
sys.path.insert(0, '/content/drive/My Drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np

#1
os.chdir("/content/drive/My Drive/results/Structures/v1_32/Adam")
ld_lossG_Adam32 = []
with open('v1_32-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_Adam32.append(float(item))

ld_lossD_Adam32 = []
with open('v1_32-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_Adam32.append(float(item))

print(len(ld_lossG_Adam32))
print(len(ld_lossD_Adam32))

os.chdir("/content/drive/My Drive/results/Structures/v1_35/Adam")

ld_lossG_Adam35 = []
with open('v1_35-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_Adam35.append(float(item))

ld_lossD_Adam35 = []
with open('v1_35-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_Adam35.append(float(item))

print(len(ld_lossG_Adam35))
print(len(ld_lossD_Adam35))

ld_lossG_Adam32_35 = np.concatenate((ld_lossG_Adam32, ld_lossG_Adam35), axis=None)
ld_lossD_Adam32_35 = np.concatenate((ld_lossD_Adam32, ld_lossD_Adam35), axis=None)

#2
os.chdir("/content/drive/My Drive/results/Structures/v1_32/RMSprop")
ld_lossG_RMSprop32 = []
with open('v1_32-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_RMSprop32.append(float(item))

ld_lossD_RMSprop32 = []
with open('v1_32-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_RMSprop32.append(float(item))

print(len(ld_lossG_RMSprop32))
print(len(ld_lossD_RMSprop32))

os.chdir("/content/drive/My Drive/results/Structures/v1_35/RMSprop")
ld_lossG_RMSprop35 = []
with open('v1_35-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_RMSprop35.append(float(item))

ld_lossD_RMSprop35 = []
with open('v1_35-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_RMSprop35.append(float(item))

print(len(ld_lossG_RMSprop35))
print(len(ld_lossD_RMSprop35))

ld_lossG_RMSprop32_35 = np.concatenate((ld_lossG_RMSprop32, ld_lossG_RMSprop35), axis=None)
ld_lossD_RMSprop32_35 = np.concatenate((ld_lossD_RMSprop32, ld_lossD_RMSprop35), axis=None)

print(len(ld_lossG_Adam32_35))
print(len(ld_lossD_Adam32_35))
print(len(ld_lossG_RMSprop32_35))
print(len(ld_lossD_RMSprop32_35))

os.chdir("/content/drive/My Drive/trash")
# Out:
# 1300
# 1300
# 1000
# 1000
# 1300
# 1300
# 1000
# 1000
# 2300
# 2300
# 2300
# 2300

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
plt.grid(color='black')
plt.title("Generator and Discriminator Loss During Training", color='black', size = 20)
#plt.title("Discriminator Loss During Training", color='black', size = 20)

plt.plot(ld_lossG_Adam32_35,label="Adam Generator (bs = 4096)", color='#00FFFF')
plt.plot(ld_lossD_Adam32_35,label="Adam Discriminator (bs = 4096)", color='yellow')

plt.plot(ld_lossG_RMSprop32_35,label="RMSprop Generator (bs = 4096)", color='#0000FF')
plt.plot(ld_lossD_RMSprop32_35,label="RMSprop Discriminator (bs = 4096)", color='#FF0000')

plt.rc('font', size=15)

plt.xlabel("Epochs", color='black', size = 13)
plt.ylabel("Loss", color='black', size=13)
ax.tick_params(axis='x', colors='black')
ax.tick_params(axis='y', colors='black')
import matplotlib.ticker as plticker
loc = plticker.MultipleLocator(base=200)
locY = plticker.MultipleLocator(base=5)
ax.xaxis.set_major_locator(loc)
ax.yaxis.set_major_locator(locY)
#plt.xlim(0,2300)
plt.ylim(0,15)
plt.legend()
fig.savefig('Losses_4_manyEpochs_BS4096' + '.png')

# %% [markdown]
# #RESULT №3 - three losses

# %%
import os
from google.colab import drive
drive.mount('/content/drive/')
import sys
sys.path.insert(0, '/content/drive/My Drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import numpy as np

#1
os.chdir("/content/drive/My Drive/results/Structures/v1_14/Adam")
ld_lossG_Adam32 = []
with open('v1_14-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_Adam32.append(float(item))

DGz2_Adam32 = []
with open('v1_14-DGz2_Loss_ep.txt', 'r') as f:
    for item in f:
        DGz2_Adam32.append(float(item))


ld_lossD_Adam32 = []
with open('v1_14-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_Adam32.append(float(item))

D_x_Adam32 = []
with open('v1_14-Dx_Loss_ep.txt', 'r') as f:
    for item in f:
        D_x_Adam32.append(float(item))

DGz1_Adam32 = []
with open('v1_14-DGz1_Loss_ep.txt', 'r') as f:
    for item in f:
        DGz1_Adam32.append(float(item))


print(len(ld_lossG_Adam32))
print(len(ld_lossD_Adam32))
print(len(D_x_Adam32))
print(len(DGz1_Adam32))
print(len(DGz2_Adam32))
print()

#1a
os.chdir("/content/drive/My Drive/results/Structures/v1_15/RMSprop")
ld_lossG_RMSprop32 = []
with open('v1_15-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_RMSprop32.append(float(item))

DGz2_RMSprop32 = []
with open('v1_15-DGz2_Loss_ep.txt', 'r') as f:
    for item in f:
        DGz2_RMSprop32.append(float(item))


ld_lossD_RMSprop32 = []
with open('v1_15-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_RMSprop32.append(float(item))

D_x_RMSprop32 = []
with open('v1_15-Dx_Loss_ep.txt', 'r') as f:
    for item in f:
        D_x_RMSprop32.append(float(item))

DGz1_RMSprop32 = []
with open('v1_15-DGz1_Loss_ep.txt', 'r') as f:
    for item in f:
        DGz1_RMSprop32.append(float(item))


print(len(ld_lossG_RMSprop32))
print(len(ld_lossD_RMSprop32))
print(len(D_x_RMSprop32))
print(len(DGz1_RMSprop32))
print(len(DGz2_RMSprop32))
print()

#2
os.chdir("/content/drive/My Drive/results/Structures/v1_30/Adam")
ld_lossG_Adam256 = []
with open('v1_30-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_Adam256.append(float(item))

DGz2_Adam256 = []
with open('v1_30-DGz2_Loss_ep.txt', 'r') as f:
    for item in f:
        DGz2_Adam256.append(float(item))


ld_lossD_Adam256 = []
with open('v1_30-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_Adam256.append(float(item))

D_x_Adam256 = []
with open('v1_30-Dx_Loss_ep.txt', 'r') as f:
    for item in f:
        D_x_Adam256.append(float(item))

DGz1_Adam256 = []
with open('v1_30-DGz1_Loss_ep.txt', 'r') as f:
    for item in f:
        DGz1_Adam256.append(float(item))


print(len(ld_lossG_Adam256))
print(len(ld_lossD_Adam256))
print(len(D_x_Adam256))
print(len(DGz1_Adam256))
print(len(DGz2_Adam256))
print()

#2a
os.chdir("/content/drive/My Drive/results/Structures/v1_18/RMSprop")
ld_lossG_RMSprop256 = []
with open('v1_18-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_RMSprop256.append(float(item))

DGz2_RMSprop256 = []
with open('v1_18-DGz2_Loss_ep.txt', 'r') as f:
    for item in f:
        DGz2_RMSprop256.append(float(item))


ld_lossD_RMSprop256 = []
with open('v1_18-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_RMSprop256.append(float(item))

D_x_RMSprop256 = []
with open('v1_18-Dx_Loss_ep.txt', 'r') as f:
    for item in f:
        D_x_RMSprop256.append(float(item))

DGz1_RMSprop256 = []
with open('v1_18-DGz1_Loss_ep.txt', 'r') as f:
    for item in f:
        DGz1_RMSprop256.append(float(item))


print(len(ld_lossG_RMSprop256))
print(len(ld_lossD_RMSprop256))
print(len(D_x_RMSprop256))
print(len(DGz1_RMSprop256))
print(len(DGz2_RMSprop256))
print()

#3
os.chdir("/content/drive/My Drive/results/Structures/v1_25/Adam")
ld_lossG_Adam1024 = []
with open('v1_25-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_Adam1024.append(float(item))

DGz2_Adam1024 = []
with open('v1_25-DGz2_Loss_ep.txt', 'r') as f:
    for item in f:
        DGz2_Adam1024.append(float(item))


ld_lossD_Adam1024 = []
with open('v1_25-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_Adam1024.append(float(item))

D_x_Adam1024 = []
with open('v1_25-Dx_Loss_ep.txt', 'r') as f:
    for item in f:
        D_x_Adam1024.append(float(item))

DGz1_Adam1024 = []
with open('v1_25-DGz1_Loss_ep.txt', 'r') as f:
    for item in f:
        DGz1_Adam1024.append(float(item))


print(len(ld_lossG_Adam1024))
print(len(ld_lossD_Adam1024))
print(len(D_x_Adam1024))
print(len(DGz1_Adam1024))
print(len(DGz2_Adam1024))
print()

#3a
os.chdir("/content/drive/My Drive/results/Structures/v1_25/RMSprop")
ld_lossG_RMSprop1024 = []
with open('v1_25-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_RMSprop1024.append(float(item))

DGz2_RMSprop1024 = []
with open('v1_25-DGz2_Loss_ep.txt', 'r') as f:
    for item in f:
        DGz2_RMSprop1024.append(float(item))


ld_lossD_RMSprop1024 = []
with open('v1_25-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_RMSprop1024.append(float(item))

D_x_RMSprop1024 = []
with open('v1_25-Dx_Loss_ep.txt', 'r') as f:
    for item in f:
        D_x_RMSprop1024.append(float(item))

DGz1_RMSprop1024 = []
with open('v1_25-DGz1_Loss_ep.txt', 'r') as f:
    for item in f:
        DGz1_RMSprop1024.append(float(item))


print(len(ld_lossG_RMSprop1024))
print(len(ld_lossD_RMSprop1024))
print(len(D_x_RMSprop1024))
print(len(DGz1_RMSprop1024))
print(len(DGz2_RMSprop1024))
print()

#4
os.chdir("/content/drive/My Drive/results/Structures/v1_32/Adam")
ld_lossG_Adam4096 = []
with open('v1_32-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_Adam4096.append(float(item))

DGz2_Adam4096 = []
with open('v1_32-DGz2_Loss_ep.txt', 'r') as f:
    for item in f:
        DGz2_Adam4096.append(float(item))


ld_lossD_Adam4096 = []
with open('v1_32-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_Adam4096.append(float(item))

D_x_Adam4096 = []
with open('v1_32-Dx_Loss_ep.txt', 'r') as f:
    for item in f:
        D_x_Adam4096.append(float(item))

DGz1_Adam4096 = []
with open('v1_32-DGz1_Loss_ep.txt', 'r') as f:
    for item in f:
        DGz1_Adam4096.append(float(item))


print(len(ld_lossG_Adam4096))
print(len(ld_lossD_Adam4096))
print(len(D_x_Adam4096))
print(len(DGz1_Adam4096))
print(len(DGz2_Adam4096))
print()

#4a
os.chdir("/content/drive/My Drive/results/Structures/v1_32/RMSprop")
ld_lossG_RMSprop4096 = []
with open('v1_32-G_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossG_RMSprop4096.append(float(item))

DGz2_RMSprop4096 = []
with open('v1_32-DGz2_Loss_ep.txt', 'r') as f:
    for item in f:
        DGz2_RMSprop4096.append(float(item))


ld_lossD_RMSprop4096 = []
with open('v1_32-D_Loss_ep.txt', 'r') as f:
    for item in f:
        ld_lossD_RMSprop4096.append(float(item))

D_x_RMSprop4096 = []
with open('v1_32-Dx_Loss_ep.txt', 'r') as f:
    for item in f:
        D_x_RMSprop4096.append(float(item))

DGz1_RMSprop4096 = []
with open('v1_32-DGz1_Loss_ep.txt', 'r') as f:
    for item in f:
        DGz1_RMSprop4096.append(float(item))


print(len(ld_lossG_RMSprop4096))
print(len(ld_lossD_RMSprop4096))
print(len(D_x_RMSprop4096))
print(len(DGz1_RMSprop4096))
print(len(DGz2_RMSprop4096))
print()

os.chdir("/content/drive/My Drive/trash")
# Out:
# 1000
# 1000
# 1000
# 1000
# 1000
#
# 1000
# 1000
# 1000
# 1000
# 1000
#
# 1000
# 1000
# 1000
# 1000
# 1000
#
# 1000
# 1000
# 1000
# 1000
# 1000
#
# 1600
# 1600
# 1600
# 1600
# 1600
#
# 1600
# 1600
# 1600
# 1600
# 1600
#
# 1300
# 1300
# 1300
# 1300
# 1300
#
# 1300
# 1300
# 1300
# 1300
# 1300

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
plt.grid(color='black')
plt.title("Generator and Discriminator Output During Training", color='black', size = 20)
#plt.title("Discriminator Loss During Training", color='black', size = 20)

# plt.plot(D_x_Adam4096,label="D(x) [Adam; (bs = 4096)]", color='#330019')
# plt.plot(DGz1_Adam4096,label="DG(z1) [Adam; (bs = 4096)]", color='#CC0066')
# plt.plot(DGz2_Adam4096,label="DG(z2) [Adam; (bs = 4096)]", color='#999900')
# plt.rc('font', size=15) 

plt.plot(D_x_RMSprop32,label="D(x) [RMSprop; (bs = 32)]", color='#330019')
plt.plot(DGz1_RMSprop32,label="DG(z1) [RMSprop; (bs = 32)]", color='#CC0066')
plt.plot(DGz2_RMSprop32,label="DG(z2) [RMSprop; (bs = 32)]", color='#999900')
plt.rc('font', size=15) 

# plt.plot(D_x_RMSprop32,label="D_x_RMSprop32 (bs = 4096)", color='#001933')
# plt.plot(DGz1_RMSprop32,label="DGz1_RMSprop32 (bs = 4096)", color='#0000FF')
# plt.plot(DGz2_RMSprop32,label="DGz2_RMSprop32 (bs = 4096)", color='#00994C')
# plt.plot(ld_lossD_Adam32_35,label="Adam Discriminator (bs = 4096)", color='yellow')

# plt.plot(ld_lossG_RMSprop32_35,label="RMSprop Generator (bs = 4096)", color='#0000FF')
# plt.plot(ld_lossD_RMSprop32_35,label="RMSprop Discriminator (bs = 4096)", color='#FF0000')

plt.xlabel("Epochs", color='black', size = 13)
plt.ylabel("Output", color='black', size=13)
ax.tick_params(axis='x', colors='black')
ax.tick_params(axis='y', colors='black')
import matplotlib.ticker as plticker
loc = plticker.MultipleLocator(base=150)
locY = plticker.MultipleLocator(base=0.1)
ax.xaxis.set_major_locator(loc)
ax.yaxis.set_major_locator(locY)
#plt.xlim(0,2300)
plt.ylim(0,1)
plt.legend()
fig.savefig('Losses2-Result_nb3_Output_RMSprop32' + '.png')
#fig.savefig('Losses2-Result_nb2_bs4096_discr' + '.png')
